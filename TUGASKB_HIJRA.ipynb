# %% [markdown]
# <a href="https://colab.research.google.com/github/hijraotji/ProgramSVM_F55121051/blob/main/TUGASKB_HIJRA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

hi=pd.read_csv('./wine.csv')
hi.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality style
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
hi.shape
# Out:
# (6497, 13)

# %%
hi.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'style'],
#       dtype='object')

# %%
hi.describe().T
# Out:
#                        count        mean        std      min       25%  \
# fixed_acidity         6497.0    7.215307   1.296434  3.80000   6.40000
# volatile_acidity      6497.0    0.339666   0.164636  0.08000   0.23000
# citric_acid           6497.0    0.318633   0.145318  0.00000   0.25000
# residual_sugar        6497.0    5.443235   4.757804  0.60000   1.80000
# chlorides             6497.0    0.056034   0.035034  0.00900   0.03800
# free_sulfur_dioxide   6497.0   30.525319  17.749400  1.00000  17.00000
# total_sulfur_dioxide  6497.0  115.744574  56.521855  6.00000  77.00000
# density               6497.0    0.994697   0.002999  0.98711   0.99234
# pH                    6497.0    3.218501   0.160787  2.72000   3.11000
# sulphates             6497.0    0.531268   0.148806  0.22000   0.43000
# alcohol               6497.0   10.491801   1.192712  8.00000   9.50000
# quality               6497.0    5.818378   0.873255  3.00000   5.00000
#
# ...

# %%
hi.compare
# Out:
# <bound method DataFrame.compare of       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
X=hi.iloc[:,1:32].values # x
y=hi.iloc[:,0].values # y

# %%
sns.pairplot(hi,vars=['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
       'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality', 'style'])
